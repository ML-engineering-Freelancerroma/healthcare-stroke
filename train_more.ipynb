# %%
import pandas as pd


results_df = pd.DataFrame(
    {
        'Model': [],
        'Accuracy': [],
        'Recall': [],
        'ROC-AUC': [],
        'PR-AUC': [],
    }
).astype(
    {
        'Model': str,
        'Accuracy': float,
        'Recall': float,
        'ROC-AUC': float,
        'PR-AUC': float,
    }
)

best_params_df = pd.DataFrame(
    columns=['Model'],
    dtype=object
).astype(
    {
        'Model': str
    }
)

# %%
from module import (
    evaluate_and_append,
    X,
    y,
    skf,
    add_best_params
)

from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.under_sampling import RandomUnderSampler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV


pipeline_rf = ImbPipeline([
    ('rus', RandomUnderSampler(random_state=42)),
    ('rf', RandomForestClassifier(random_state=42, n_jobs=-1))
])

param_grid_rf = {
    'rus__sampling_strategy': [0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
    'rf__n_estimators': [300, 500, 800, 1200, 2000],
    'rf__max_depth': [6, 8, 10, 12, 15, 20, None],
    'rf__min_samples_leaf': [1, 2, 5, 10, 20, 50],
    'rf__min_samples_split': [2, 5, 10, 20, 50],
    'rf__max_features': ['sqrt', 'log2', 0.3, 0.5, 0.7, None],
    'rf__criterion': ['gini', 'entropy'],
    'rf__class_weight': [None, 'balanced', 'balanced_subsample']
}

search_rf = RandomizedSearchCV(
    estimator=pipeline_rf,
    param_distributions=param_grid_rf,
    n_iter=200,
    cv=skf,
    scoring='recall',
    n_jobs=-1,
    random_state=42,
    verbose=1
)

search_rf.fit(X, y)

print('RandomForest+RUS best params:', search_rf.best_params_)
print('RandomForest+RUS best recall:', search_rf.best_score_)

results_df = evaluate_and_append(
    model_name='RandomForestClassifier+RUS',
    best_estimator=search_rf.best_estimator_,
    X=X, y=y, cv=skf,
    results_df=results_df
)

print(results_df)

best_params_df = add_best_params(
    'RandomForest+RUS',
    search_rf,
    best_params_df
)

print(best_params_df.to_string())
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# RandomForest+RUS best params: {'rus__sampling_strategy': 0.7, 'rf__n_estimators': 500, 'rf__min_samples_split': 20, 'rf__min_samples_leaf': 50, 'rf__max_features': 'log2', 'rf__max_depth': 15, 'rf__criterion': 'gini', 'rf__class_weight': 'balanced'}
# RandomForest+RUS best recall: 0.9355618776671408
#                         Model  Accuracy    Recall   ROC-AUC    PR-AUC
# 0  RandomForestClassifier+RUS  0.617332  0.935829  0.815808  0.148762
#               Model  rus__sampling_strategy  rf__n_estimators  rf__min_samples_split  rf__min_samples_leaf rf__max_features  rf__max_depth rf__criterion rf__class_weight
# 0  RandomForest+RUS                     0.7             500.0                   20.0                  50.0             log2           15.0          gini         balanced

# %%
from module import (
    evaluate_and_append,
    X,
    y,
    skf,
    add_best_params
)

from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.under_sampling import RandomUnderSampler
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV


pipeline_xgb = ImbPipeline([
    ('rus', RandomUnderSampler(random_state=42)),
    ('xgb', XGBClassifier(
        random_state=42,
        n_jobs=-1,
        verbosity=0,
        eval_metric='aucpr',
        tree_method='hist'
    ))
])

param_grid_xgb = {
    'rus__sampling_strategy': [0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
    'xgb__n_estimators': [800, 1200, 1500, 2000, 2500, 3000],
    'xgb__learning_rate': [0.005, 0.008, 0.01, 0.015, 0.02, 0.03],
    'xgb__max_depth': [4, 5, 6, 7, 8],
    'xgb__min_child_weight': [5, 8, 10, 15, 20, 30],
    'xgb__gamma': [0.1, 0.2, 0.3, 0.5],
    'xgb__reg_lambda': [5, 10, 15, 20, 30, 50],
    'xgb__reg_alpha': [0.5, 1, 2, 5],
    'xgb__subsample': [0.5, 0.6, 0.7, 0.8],
    'xgb__colsample_bytree': [0.5, 0.6, 0.7, 0.8],
    'xgb__scale_pos_weight': [1.0]
}

search_xgb = RandomizedSearchCV(
    estimator=pipeline_xgb,
    param_distributions=param_grid_xgb,
    n_iter=200,
    cv=skf,
    scoring='recall',
    n_jobs=1,
    random_state=42,
    verbose=1
)

search_xgb.fit(X, y)

print('XGBoost+RUS best params:', search_xgb.best_params_)
print('XGBoost+RUS best recall:', search_xgb.best_score_)

results_df = evaluate_and_append(
    model_name='XGBoostClassifier+RUS',
    best_estimator=search_xgb.best_estimator_,
    X=X, y=y, cv=skf,
    results_df=results_df
)

print(results_df)

best_params_df = add_best_params(
    'XGBoost+RUS',
    search_xgb,
    best_params_df
)

print(best_params_df.to_string())
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# XGBoost+RUS best params: {'xgb__subsample': 0.8, 'xgb__scale_pos_weight': 1.0, 'xgb__reg_lambda': 20, 'xgb__reg_alpha': 5, 'xgb__n_estimators': 1500, 'xgb__min_child_weight': 8, 'xgb__max_depth': 6, 'xgb__learning_rate': 0.01, 'xgb__gamma': 0.1, 'xgb__colsample_bytree': 0.5, 'rus__sampling_strategy': 1.0}
# XGBoost+RUS best recall: 0.903271692745377
#                         Model  Accuracy    Recall   ROC-AUC    PR-AUC
# 0  RandomForestClassifier+RUS  0.617332  0.935829  0.815808  0.148762
# 1       XGBoostClassifier+RUS  0.653876  0.903743  0.828269  0.146321
#               Model  rus__sampling_strategy  rf__n_estimators  rf__min_samples_split  rf__min_samples_leaf rf__max_features  rf__max_depth rf__criterion rf__class_weight  xgb__subsample  xgb__scale_pos_weight  xgb__reg_lambda  xgb__reg_alpha  xgb__n_estimators  xgb__min_child_weight  xgb__max_depth  xgb__learning_rate  xgb__gamma  xgb__colsample_bytree
# 0  RandomForest+RUS                     0.7             500.0                   20.0                  50.0             log2           15.0          gini         balanced             NaN                    NaN              NaN             NaN                NaN                    NaN             NaN                 NaN         NaN                    NaN
# 1       XGBoost+RUS                     1.0               NaN                    NaN                   NaN              NaN            NaN           NaN              NaN             0.8                    1.0             20.0             5.0             1500.0                    8.0             6.0                0.01         0.1                    0.5

# %%
from module import (
    evaluate_and_append,
    X,
    y,
    skf,
    CAT_FEATURES,
    add_best_params
)

from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.under_sampling import RandomUnderSampler
from catboost import CatBoostClassifier
from sklearn.model_selection import RandomizedSearchCV
import numpy as np


pipeline_cb = ImbPipeline([
    ('rus', RandomUnderSampler(random_state=42)),
    ('cb', CatBoostClassifier(
        random_state=42,
        thread_count=-1,
        verbose=False,
        od_type='Iter',
        od_wait=50,
        eval_metric='Recall',
        cat_features=CAT_FEATURES
    ))
])

param_dist_cb = {
    'rus__sampling_strategy': [0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
    'cb__iterations': [800, 1000, 1200, 1500, 2000, 2500, 3000],
    'cb__learning_rate': [0.002, 0.005, 0.008, 0.01, 0.015, 0.02, 0.03, 0.05, 0.08],
    'cb__depth': [3, 4, 5, 6, 7, 8, 9, 10],
    'cb__l2_leaf_reg': [1, 3, 5, 7, 10, 15, 20, 30, 50],
    'cb__bagging_temperature': [0, 0.5, 1, 1.5, 2],
    'cb__random_strength': [1, 2, 3, 5, 10],
    'cb__border_count': [32, 64, 128, 254],
    'cb__grow_policy': ['SymmetricTree', 'Depthwise', 'Lossguide'],
    'cb__min_data_in_leaf': [1, 3, 5, 10, 20]
}

search_cb = RandomizedSearchCV(
    estimator=pipeline_cb,
    param_distributions=param_dist_cb,
    n_iter=200,
    cv=skf,
    scoring='recall',
    n_jobs=1,
    random_state=42,
    verbose=1
)

search_cb.fit(X, y)

print('CatBoost+RUS best params:', search_cb.best_params_)
print('CatBoost+RUS best recall:', search_cb.best_score_)

results_df = evaluate_and_append(
    model_name='CatBoostClassifier+RUS',
    best_estimator=search_cb.best_estimator_,
    X=X, y=y, cv=skf,
    results_df=results_df
)

print(results_df)

best_params_df = add_best_params(
    'CatBoost+RUS',
    search_cb,
    best_params_df
)

print(best_params_df.to_string())
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# CatBoost+RUS best params: {'rus__sampling_strategy': 1.0, 'cb__random_strength': 5, 'cb__min_data_in_leaf': 5, 'cb__learning_rate': 0.008, 'cb__l2_leaf_reg': 3, 'cb__iterations': 800, 'cb__grow_policy': 'SymmetricTree', 'cb__depth': 3, 'cb__border_count': 32, 'cb__bagging_temperature': 1}
# CatBoost+RUS best recall: 0.9034139402560456
#                         Model  Accuracy    Recall   ROC-AUC    PR-AUC
# 0  RandomForestClassifier+RUS  0.617332  0.935829  0.815808  0.148762
# 1       XGBoostClassifier+RUS  0.653876  0.903743  0.828269  0.146321
# 2      CatBoostClassifier+RUS  0.662490  0.903743  0.830554  0.159995
#               Model  rus__sampling_strategy  rf__n_estimators  rf__min_samples_split  rf__min_samples_leaf rf__max_features  rf__max_depth rf__criterion rf__class_weight  xgb__subsample  xgb__scale_pos_weight  xgb__reg_lambda  xgb__reg_alpha  xgb__n_estimators  xgb__min_child_weight  xgb__max_depth  xgb__learning_rate  xgb__gamma  xgb__colsample_bytree  cb__random_strength  cb__min_data_in_leaf  cb__learning_rate  cb__l2_leaf_reg  cb__iterations cb__grow_policy  cb__depth  cb__border_count  cb__bagging_temperature
# 0  RandomForest+RUS                     0.7             500.0                   20.0                  50.0             log2           15.0          gini         balanced             NaN                    NaN              NaN             NaN                NaN                    NaN             NaN                 NaN         NaN                    NaN                  NaN                   NaN                NaN              NaN             NaN             NaN        NaN               NaN                      NaN
# 1       XGBoost+RUS                     1.0               NaN                    NaN                   NaN              NaN            NaN           NaN              NaN             0.8                    1.0             20.0             5.0             1500.0                    8.0             6.0                0.01         0.1                    0.5                  NaN                   NaN                NaN              NaN             NaN             NaN        NaN               NaN                      NaN
# 2      CatBoost+RUS                     1.0               NaN                    NaN                   NaN              NaN            NaN           NaN              NaN             NaN                    NaN              NaN             NaN                NaN                    NaN             NaN                 NaN         NaN                    NaN                  5.0                   5.0              0.008              3.0           800.0   SymmetricTree        3.0              32.0                      1.0

# %%
results_df.to_csv('results_train_more.csv', index=False)
best_params_df.to_csv('best_params.csv', index=False)
